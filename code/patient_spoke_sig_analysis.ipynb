# %% [markdown]
# # Import modules

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.spatial.distance import cdist, pdist, squareform
import subprocess
import time
import multiprocessing as mp
import matplotlib.pyplot as plt
import os
from collections import Counter
import seaborn as sns
import io
import requests
from sklearn.ensemble import RandomForestClassifier
import joblib

# %% [markdown]
# # Initialize file paths

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()),'data')
model_path = os.path.join(os.path.dirname(os.getcwd()),'model')
node_info_file = os.path.join(data_path, 'node_info_df.tsv')
workshop_psev_file = os.path.join(data_path, 'workshop_psevs.npy')
int_cohort_filename = os.path.join(data_path, 'example_cohort.tsv')
new_patient_info_filename = os.path.join(data_path, 'random_patient_info.tsv')
new_patient_spokesig_filename = os.path.join(data_path, 'random_patient_spokesigs.npy')
mean_node_val_filename = os.path.join(data_path, 'mean_node_val_df.tsv')
random_forest_model = os.path.join(model_path, 'random_forest_bc_cc_ibd.joblib')

# %% [markdown]
# # Load SPOKE file

# %%
print('loading SPOKE nodes ...')
node_info_df = pd.read_csv(node_info_file, sep='\t', header=0, index_col=False)

# Diseases for workshop
diseases = ['DOID:9778', 'DOID:1612', 'DOID:219']
disease_names = ['_'.join(node_info_df[node_info_df.Node==disease].Node_Name.values[0].split()) for disease in diseases]

print('loading Disease PSEVs for workshop ...')
psev_matrix = np.load(workshop_psev_file, allow_pickle=False)
# Out:
# loading SPOKE nodes ...
# loading Disease PSEVs for workshop ...

# %% [markdown]
# # Load initial cohort

# %%
example_cohort = pd.read_csv(int_cohort_filename, sep='\t', header=0, index_col=False)
example_cohort.head()
# Out:
#        patient_id               Ethnicity     Sex    Smoking Status  \
# 0  D00040B4CC68B5  Not Hispanic or Latino    Male      Never Smoker
# 1  D02AFFB6CD3FF9  Not Hispanic or Latino    Male      Never Smoker
# 2  D0B08BA9B1480E  Not Hispanic or Latino  Female  Unknown/Declined
# 3  D2C3A888095B14  Not Hispanic or Latino    Male      Never Smoker
# 4  D2CDF4CB78A2CA  Not Hispanic or Latino    Male      Never Smoker
#
#   patient_status                                       Race  Age  \
# 0          Alive                         White or Caucasian   60
# 1          Alive                         White or Caucasian   61
# 2          Alive  Native Hawaiian or Other Pacific Islander   51
# 3          Alive                         White or Caucasian   47
# 4          Alive                         White or Caucasian   58
#
#    Patient_Index train_or_test  SEP_Count  OMOP_Count   SPOKE_ID  label  \
# 0              0         Train        184         152  DOID:9778      0
# 1              1         Train        100          92   DOID:219      2
# 2              2         Train         46          50   DOID:219      2
# 3              3         Train         91          75  DOID:9778      0
# 4              4         Train         57          42  DOID:9778      0
#
#                     Disease
# 0  irritable_bowel_syndrome
# 1              colon_cancer
# 2              colon_cancer
# 3  irritable_bowel_syndrome
# 4  irritable_bowel_syndrome

# %% [markdown]
# # Look at cohort demographics

# %%
# use seaborn barplot to look at 'Sex','Race', and 'Ethnicity' in the example cohort
# https://seaborn.pydata.org/generated/seaborn.barplot.html

# %% [markdown]
# # Look at cohort continuous variables

# %%
# use seaborn boxplot to look at 'Age', 'OMOP_Count', and 'SEP_Count'
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %% [markdown]
# # Load initial cohort SPOKEsigs data

# %%
from mapping_functions import load_or_make_spokesig_mean_std_dist
mean_sig, std_sig, patient_to_disease_dist = load_or_make_spokesig_mean_std_dist(node_info_df, example_cohort, diseases, disease_names, data_path, load_data=True)

# %% [markdown]
# # Compare initial patients to disease PSEVs

# %%
# find closest disease to patient in initial cohort
best_match = np.array(np.array(disease_names)[np.argmin(patient_to_disease_dist, axis=1)])
print(np.sum(example_cohort.Disease.values==best_match))
#
# check if closest disease is correct
example_cohort.loc[:,'pred'] = best_match
example_cohort.loc[:,'match_correct'] = example_cohort.Disease.values == example_cohort.pred.values
match_stats_df = example_cohort[['Patient_Index', 'Disease', 'pred']].groupby(['Disease','pred']).count().reset_index().rename(columns={'Patient_Index':'Count'})
match_stats_df
# Out:
# 8722
#                     Disease                      pred  Count
# 0             breast_cancer             breast_cancer   3283
# 1             breast_cancer              colon_cancer    919
# 2             breast_cancer  irritable_bowel_syndrome   2952
# 3              colon_cancer             breast_cancer     15
# 4              colon_cancer              colon_cancer   1380
# 5              colon_cancer  irritable_bowel_syndrome    325
# 6  irritable_bowel_syndrome             breast_cancer     59
# 7  irritable_bowel_syndrome              colon_cancer    303
# 8  irritable_bowel_syndrome  irritable_bowel_syndrome   4059

# %% [markdown]
# # Visualize cohort in 3d
# (based on distance to diseases)

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# use matplotlib scatter to plot patients (by disease) using the distance matrix (patient_to_disease_dist)

# https://matplotlib.org/stable/gallery/mplot3d/scatter3d.html
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Load new patients from API

# %%
try:    
    new_cohort = pd.read_csv(new_patient_info_filename, sep='\t', header=0, index_col=False)
    print('new patient data is loaded')
    new_spoke_sigs = np.load(new_patient_spokesig_filename, allow_pickle=False)
    print('normalizing new patients ...')
    new_spoke_sigs = (new_spoke_sigs-mean_sig)/std_sig
except FileNotFoundError:
    print('SPOKE sigs of new patients have not been yet created using API. Run that first using "get_patient_spoke_sig_using_API.ipynb", before proceeding further.')
# Out:
# new patient data is loaded
# normalizing new patients ...

# %% [markdown]
# # Compare new patients to disease PSEVs

# %%
# calculate distance matrix
new_patient_to_disease_dist = cdist(new_spoke_sigs, psev_matrix, metric='cosine')
#
# find closest disease to patient in new cohort (see Compare initial patients to disease PSEVs)
best_match = 
print()
#
# check if closest disease is correct (see Compare initial patients to disease PSEVs)
new_cohort.loc[:,'pred'] = 
new_cohort.loc[:,'match_correct'] = 
match_stats_df = 
match_stats_df
# Out:
# 0.7333333333333333
#                     Disease                      pred  Patient_Index
# 0             breast_cancer             breast_cancer              5
# 1              colon_cancer              colon_cancer              2
# 2              colon_cancer  irritable_bowel_syndrome              3
# 3  irritable_bowel_syndrome              colon_cancer              1
# 4  irritable_bowel_syndrome  irritable_bowel_syndrome              4

# %% [markdown]
# # Load pre-trained random forest classifier (using initial cohort)

# %%
clf = joblib.load(random_forest_model)
# Out:
# /Users/student/py3/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.22.2.post1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /Users/student/py3/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.22.2.post1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # Test Random Forest Classifier using new patients

# %%
pred = clf.predict(new_spoke_sigs)
print(np.sum(new_cohort.sort_values('Patient_Index').label.values==pred)/len(new_cohort))
# Out:
# 1.0

# %% [markdown]
# # Create node importance table

# %%
classifier_results = pd.read_csv(mean_node_val_filename, sep='\t', header=0, index_col=False)
classifier_results.loc[:,'feature_importance'] = clf.feature_importances_

# %% [markdown]
# # Set a threshold for node importance

# %%
# select % threshold
thresh_percentile = 99
feature_thresh = np.percentile(classifier_results.feature_importance.values, thresh_percentile)

# select number of rows to show
top_n=50

# %% [markdown]
# # Look at key nodes for IBS

# %% [markdown]
# These are the top IBS nodes that pass feature importance and IBS avg sig thresholds. Nodes are sorted by their feature importance for the RF classifier

# %%
col = 'irritable bowel syndrome'
thresh = np.percentile(classifier_results[col].values, thresh_percentile)
classifier_results[(classifier_results.Node_Type!='Compound')&(classifier_results.feature_importance>feature_thresh)&(classifier_results[col]>thresh)].sort_values('feature_importance', ascending=False).head(top_n)
# Out:
#                   Node                                  Node_Name  \
# 16059             7932                                      OR2H2
# 330562       DOID:9778                   irritable bowel syndrome
# 378849  UBERON:0005304                     submucous nerve plexus
# 29951         C0022104                   Irritable bowel syndrome
# 16330            79849                                      PDZD3
# 10402           503841                                   DEFB106B
# 354462          P09093                                CEL3A_HUMAN
# 357241          P58417                                NXPH1_HUMAN
# 6630             27134                                       TJP3
# 5689            245909                                   DEFB106A
# 6035             25849                                      PARM1
# 33622      CHEBI:71031                                orphan drug
# 361387          Q3LID8                               Q3LID8_HUMAN
# 28175           B4DYM4                               B4DYM4_HUMAN
# 356594          P48764                                SL9A3_HUMAN
# 319173         D059265                              Visceral Pain
# 349600      GO:1990742                               microvesicle
# 366472          Q8N104                                D106A_HUMAN
# 6178             26002                                      MOXD1
# 24189       A0A1U9X844                           A0A1U9X844_HUMAN
# 11122             5197                                      PF4V1
# 26340           B1B154                               B1B154_HUMAN
# 375041  UBERON:0000429                             enteric plexus
# 7431              2949                                      GSTM5
# 5658             23780                                      APOL2
# 1934            116337                                      PANX3
# 338880      GO:0031727            CCR2 chemokine receptor binding
# 377605  UBERON:0003715                           splanchnic nerve
# 8984            388743                                      CAPN8
# 318642         D004884                                 Eructation
# 361893          Q53QV7                               Q53QV7_HUMAN
# 26263           B0YJ61                               B0YJ61_HUMAN
# 347025      GO:0097603     temperature-gated ion channel activity
# 31013         C0221030                    Hyperviscosity syndrome
# 327809       DOID:3660                              wheat allergy
# 347026      GO:0097604  temperature-gated cation channel activity
# 350745          J3KQL8                               J3KQL8_HUMAN
# 318436      D000074268                Guanylyl Cyclase C Agonists
# 369980          Q96QZ0                                PANX3_HUMAN
# 31247         C0235398              Diabetes mellitus exacerbated
# 330438        DOID:946                            dientamoebiasis
# 351434     N0000175456                Chloride Channel Activators
# 18653            91807                                      MYLK3
# 380394  UBERON:0008285                           rumen epithelium
# 1951            116512                                     MRGPRD
# 353590          O95049                                  ZO3_HUMAN
# 33085         C2747853              Injury associated with device
# 10568            51052                                       PRLH
# 15960            79054                                      TRPM8
# 319039         D020536                          Enzyme Activators
#
#                  Node_Type  irritable bowel syndrome  breast cancer  \
# 16059                 Gene                  0.810610      -0.410360
# 330562             Disease                  0.779609      -0.383818
# 378849             Anatomy                  0.745551      -0.516561
# 29951           SideEffect                  0.773214      -0.373545
# 16330                 Gene                  0.744267      -0.401101
# 10402                 Gene                  0.807590      -0.422422
# 354462             Protein                  0.823338      -0.482793
# 357241             Protein                  0.789322      -0.429919
# 6630                  Gene                  0.784056      -0.415899
# 5689                  Gene                  0.806375      -0.421701
# 6035                  Gene                  0.715752      -0.363412
# 33622   PharmacologicClass                  0.867499      -0.525377
# 361387             Protein                  0.799367      -0.417082
# 28175              Protein                  0.785588      -0.371304
# 356594             Protein                  0.757511      -0.467827
# 319173             Symptom                  0.878474      -0.449749
# 349600   CellularComponent                  0.749651      -0.368607
# 366472             Protein                  0.780485      -0.425413
# 6178                  Gene                  0.851786      -0.482572
# 24189              Protein                  0.810718      -0.410413
# 11122                 Gene                  0.738727      -0.422133
# 26340              Protein                  0.795031      -0.398197
# 375041             Anatomy                  0.718269      -0.547389
# 7431                  Gene                  0.714383      -0.364824
# 5658                  Gene                  0.726334      -0.350054
# 1934                  Gene                  0.751614      -0.351655
# 338880   MolecularFunction                  0.731392      -0.380476
# 377605             Anatomy                  0.769626      -0.500637
# 8984                  Gene                  0.794945      -0.398153
# 318642             Symptom                  0.866361      -0.490246
# 361893             Protein                  0.777459      -0.395223
# 26263              Protein                  0.744632      -0.401290
# 347025   MolecularFunction                  0.816299      -0.436082
# 31013           SideEffect                  0.772864      -0.374097
# 327809             Disease                  0.888897      -0.422862
# 347026   MolecularFunction                  0.792328      -0.413615
# 350745             Protein                  0.726607      -0.350193
# 318436  PharmacologicClass                  0.932142      -0.509664
# 369980             Protein                  0.718670      -0.336345
# 31247           SideEffect                  0.793856      -0.320141
# 330438             Disease                  0.842685      -0.483020
# 351434  PharmacologicClass                  0.821044      -0.384651
# 18653                 Gene                  0.718594      -0.452741
# 380394             Anatomy                  0.765270      -0.502696
# 1951                  Gene                  0.741269      -0.387624
# 353590             Protein                  0.784289      -0.416020
# 33085           SideEffect                  0.793856      -0.320141
# 10568                 Gene                  0.777162      -0.395073
# 15960                 Gene                  0.845028      -0.410917
# 319039  PharmacologicClass                  0.936439      -0.507276
#
#         colon cancer  feature_importance
# 16059      -0.345545            0.000604
# 330562     -0.376286            0.000514
# 378849      0.244602            0.000435
# 29951      -0.402031            0.000335
# 16330      -0.207085            0.000225
# 10402      -0.280413            0.000205
# 354462     -0.076467            0.000171
# 357241     -0.208624            0.000156
# 6630       -0.246271            0.000140
# 5689       -0.280131            0.000137
# 6035       -0.282756            0.000132
# 33622      -0.029024            0.000129
# 361387     -0.283470            0.000121
# 28175      -0.432276            0.000119
# 356594      0.015124            0.000113
# 319173     -0.376432            0.000112
# 349600     -0.344693            0.000101
# 366472     -0.198669            0.000095
# 6178       -0.148092            0.000086
# 24189      -0.345620            0.000084
# 11122      -0.108919            0.000083
# 26340      -0.355344            0.000082
# 375041      0.438187            0.000080
# 7431       -0.281297            0.000079
# 5658       -0.378644            0.000073
# 1934       -0.428996            0.000062
# 338880     -0.261950            0.000055
# 377605      0.126896            0.000052
# 8984       -0.355293            0.000051
# 318642     -0.159531            0.000048
# 361893     -0.319941            0.000047
# 26263      -0.207269            0.000046
# 347025     -0.250264            0.000038
# 31013      -0.444990            0.000034
# 327809     -0.511669            0.000032
# 347026     -0.278278            0.000030
# 350745     -0.378802            0.000028
# 318436     -0.263282            0.000026
# 369980     -0.405879            0.000024
# 31247      -0.720404            0.000022
# 330438     -0.141840            0.000021
# 351434     -0.490523            0.000019
# 18653       0.073280            0.000018
# 380394      0.134362            0.000018
# 1951       -0.271946            0.000017
# 353590     -0.246389            0.000015
# 33085      -0.720404            0.000015
# 10568      -0.319765            0.000015
# 15960      -0.441203            0.000015
# 319039     -0.283748            0.000014

# %% [markdown]
# # Look at key nodes for breast cancer

# %% [markdown]
# These are the top breast cancer nodes that pass feature importance and breast cancer avg sig thresholds. Nodes are sorted by their feature importance for the RF classifier

# %%
col = 'breast cancer'
thresh = np.percentile(classifier_results[col].values, thresh_percentile)
classifier_results[(classifier_results.Node_Type!='Compound')&(classifier_results.feature_importance>feature_thresh)&(classifier_results[col]>thresh)].sort_values('feature_importance', ascending=False).head(top_n)
# Out:
#                 Node                                  Node_Name  \
# 321954  DOID:0050671                       female breast cancer
# 21452     A0A024RAS2                           A0A024RAS2_HUMAN
# 1042           10647                                    SCGB1D2
# 328358     DOID:4680               breast metaplastic carcinoma
# 17008           8348                                  HIST1H2BO
# 350361        H3BN63                               H3BN63_HUMAN
# 11434          54454                                     ATAD2B
# 10669          51163                                       DBR1
# 331848        G3XAF7                               G3XAF7_HUMAN
# 21498     A0A024RB16                           A0A024RB16_HUMAN
# 330559     DOID:9773  female breast upper-outer quadrant cancer
# 319069       D047072                       Aromatase Inhibitors
# 3982          170689                                   ADAMTS15
# 17823          85320                                     ABCC11
# 3192          147407                                   SLC25A52
# 26122         A8MV23                                SERP3_HUMAN
# 14369         645922                                   S100A7L2
# 20829     A0A024R6W8                           A0A024R6W8_HUMAN
# 19202           9618                                      TRAF4
# 364087        Q6P4D7                               Q6P4D7_HUMAN
# 319379        D6R9V8                               D6R9V8_HUMAN
# 33366         C9JYQ7                               C9JYQ7_HUMAN
# 19608     A0A024QZ19                           A0A024QZ19_HUMAN
# 15236           7107                                    GPR137B
# 21499     A0A024RB17                           A0A024RB17_HUMAN
# 7779             318                                      NUDT2
# 322347  DOID:0060079       Her2-receptor positive breast cancer
# 13524           5892                                     RAD51D
# 329560     DOID:7076                lipid-rich breast carcinoma
# 352588        O15405                                 TOX3_HUMAN
# 5347           23307                                     FKBP15
# 6477          266747                                       RGL4
# 17181          83940                                     TATDN1
# 326454    DOID:13972  female breast lower-outer quadrant cancer
# 350450        H3BU64                               H3BU64_HUMAN
# 9178          390667                                       PTX4
# 365958        Q8IU91                               Q8IU91_HUMAN
# 25296         A6NC51                                T150B_HUMAN
# 28508         B7Z1M8                               B7Z1M8_HUMAN
# 370899        Q9BXX3                                AN30A_HUMAN
# 367256        Q8NCR6                                SMRP1_HUMAN
# 2514          129450                                       TYW5
# 329865     DOID:7843                    female breast carcinoma
# 27934         B4DTF2                               B4DTF2_HUMAN
# 366062        Q8IVJ6                               Q8IVJ6_HUMAN
# 328896     DOID:5592                 breast papillary carcinoma
# 8670          375035                                     SFT2D2
# 12237          55573                                       CDV3
# 15383         728113                                    ANXA8L1
# 374537        Q9Y5R2                                MMP24_HUMAN
#
#                  Node_Type  irritable bowel syndrome  breast cancer  \
# 321954             Disease                 -0.579696       0.516392
# 21452              Protein                 -0.569888       0.490503
# 1042                  Gene                 -0.587202       0.499129
# 328358             Disease                 -0.569895       0.482652
# 17008                 Gene                 -0.580092       0.487177
# 350361             Protein                 -0.642653       0.486637
# 11434                 Gene                 -0.599100       0.496728
# 10669                 Gene                 -0.574061       0.510012
# 331848             Protein                 -0.578582       0.484428
# 21498              Protein                 -0.614551       0.509087
# 330559             Disease                 -0.578807       0.514434
# 319069  PharmacologicClass                 -0.553364       0.547633
# 3982                  Gene                 -0.566287       0.493747
# 17823                 Gene                 -0.582093       0.511036
# 3192                  Gene                 -0.598781       0.511801
# 26122              Protein                 -0.640835       0.515198
# 14369                 Gene                 -0.596840       0.513784
# 20829              Protein                 -0.593659       0.499591
# 19202                 Gene                 -0.583243       0.505097
# 364087             Protein                 -0.573363       0.487061
# 319379             Protein                 -0.591486       0.512005
# 33366              Protein                 -0.592060       0.499353
# 19608              Protein                 -0.583234       0.505130
# 15236                 Gene                 -0.584370       0.492853
# 21499              Protein                 -0.614551       0.509087
# 7779                  Gene                 -0.586762       0.499126
# 322347             Disease                 -0.557324       0.476737
# 13524                 Gene                 -0.623227       0.515841
# 329560             Disease                 -0.568685       0.484437
# 352588             Protein                 -0.636295       0.516076
# 5347                  Gene                 -0.573678       0.499918
# 6477                  Gene                 -0.605930       0.501439
# 17181                 Gene                 -0.578481       0.486490
# 326454             Disease                 -0.521189       0.515772
# 350450             Protein                 -0.616899       0.520189
# 9178                  Gene                 -0.557149       0.482221
# 365958             Protein                 -0.591333       0.485677
# 25296              Protein                 -0.586027       0.488637
# 28508              Protein                 -0.609529       0.501646
# 370899             Protein                 -0.615863       0.518903
# 367256             Protein                 -0.571019       0.477480
# 2514                  Gene                 -0.591524       0.497093
# 329865             Disease                 -0.571726       0.485561
# 27934              Protein                 -0.596221       0.499739
# 366062             Protein                 -0.591333       0.485677
# 328896             Disease                 -0.579705       0.483128
# 8670                  Gene                 -0.589156       0.519284
# 12237                 Gene                 -0.591502       0.511994
# 15383                 Gene                 -0.596235       0.499722
# 374537             Protein                 -0.597228       0.481933
#
#         colon cancer  feature_importance
# 321954     -0.638748            0.006465
# 21452      -0.555778            0.005541
# 1042       -0.546402            0.005509
# 328358     -0.520011            0.005257
# 17008      -0.510167            0.005187
# 350361     -0.346831            0.004944
# 11434      -0.502220            0.004848
# 10669      -0.624084            0.004799
# 331848     -0.501504            0.004767
# 21498      -0.511061            0.004762
# 330559     -0.630967            0.003043
# 319069     -0.829562            0.002189
# 3982       -0.574098            0.002162
# 17823      -0.603222            0.001364
# 3192       -0.567185            0.000756
# 26122      -0.471428            0.000616
# 14369      -0.582671            0.000520
# 20829      -0.524546            0.000493
# 19202      -0.576448            0.000447
# 364087     -0.528167            0.000435
# 319379     -0.587554            0.000430
# 33366      -0.527360            0.000422
# 19608      -0.576618            0.000415
# 15236      -0.525141            0.000397
# 21499      -0.511061            0.000395
# 7779       -0.546033            0.000390
# 322347     -0.528372            0.000383
# 13524      -0.522971            0.000278
# 329560     -0.531110            0.000276
# 352588     -0.492839            0.000245
# 5347       -0.581372            0.000229
# 6477       -0.500952            0.000228
# 17181      -0.512536            0.000225
# 326454     -0.778486            0.000177
# 350450     -0.556719            0.000166
# 9178       -0.552066            0.000165
# 365958     -0.477249            0.000159
# 25296      -0.510474            0.000145
# 28508      -0.493859            0.000136
# 370899     -0.555806            0.000136
# 367256     -0.492700            0.000131
# 2514       -0.518635            0.000125
# 329865     -0.527328            0.000123
# 27934      -0.523453            0.000113
# 366062     -0.477249            0.000112
# 328896     -0.496883            0.000107
# 8670       -0.628331            0.000099
# 12237      -0.587460            0.000096
# 15383      -0.523338            0.000091
# 374537     -0.450733            0.000086

# %% [markdown]
# # Look at key nodes for colon cancer

# %% [markdown]
# These are the top colon cancer nodes that pass feature importance and colon cancer avg sig thresholds. Nodes are sorted by their feature importance for the RF classifier

# %%
col = 'colon cancer'
thresh = np.percentile(classifier_results[col].values, thresh_percentile)
classifier_results[(classifier_results.Node_Type!='Compound')&(classifier_results.feature_importance>feature_thresh)&(classifier_results[col]>thresh)].sort_values('feature_importance', ascending=False).head(top_n)
# Out:
#                   Node                                          Node_Name  \
# 3846            164714                                              TTLL8
# 326959       DOID:1988                                    rectum lymphoma
# 18257            89790                                           SIGLEC10
# 29084           B7ZL06                                       B7ZL06_HUMAN
# 361133          Q2M2I3                                        FA83E_HUMAN
# 326958       DOID:1984                                    rectal neoplasm
# 351164     N0000007151                                         Folic Acid
# 11816            55001                                              TTC22
# 388239          W8FW32                                       W8FW32_HUMAN
# 380037  UBERON:0007181             serosa of infundibulum of uterine tube
# 319107         D054368                                          Laxatives
# 24153       A0A1L6Z9X4                                   A0A1L6Z9X4_HUMAN
# 387260  UBERON:3010819                        gastrointestinal peritoneum
# 362162          Q59G28                                       Q59G28_HUMAN
# 7223            286187                                            PPP1R42
# 5914            256536                                            TCERG1L
# 33647      CHEBI:77962                                   food antioxidant
# 357701          P86452                                        ZBED6_HUMAN
# 371810          Q9H8M2                                         BRD9_HUMAN
# 329510       DOID:6959                       rectal cloacogenic carcinoma
# 329683       DOID:7401  colonic L-cell glucagon-like peptide producing...
# 329425       DOID:6727                         colon small cell carcinoma
# 350552          I1SRC5                                       I1SRC5_HUMAN
# 24151       A0A1L2EC20                                   A0A1L2EC20_HUMAN
# 11675            54854                                             FAM83E
# 351372     N0000171009                         Fibroblast Growth Factor 7
# 3065            144715                                              RAD9B
# 30768         C0151618                                        Embolus leg
# 3010            143570                                              XRRA1
# 3861            165324                                             UBXN2A
# 16516            80174                                              DBF4B
# 360819          Q15907                                        RB11B_HUMAN
# 17096            83719                                              YPEL3
# 363140          Q5VWI1                                        TCRGL_HUMAN
# 5795            254042                                            METAP1D
# 21803       A0A024RD58                                   A0A024RD58_HUMAN
# 7426              2941                                              GSTA4
# 370287          Q99795                                        GPA33_HUMAN
# 929          105372382                                              FFAR2
# 22654       A0A0A0MS93                                   A0A0A0MS93_HUMAN
# 329026       DOID:5777                     rectum neuroendocrine neoplasm
# 4775            221357                                              GSTA5
# 327058        DOID:219                                       colon cancer
# 21719       A0A024RCH0                                   A0A024RCH0_HUMAN
# 7504             29901                                             SAC3D1
# 327458       DOID:3039                               cecum adenocarcinoma
# 29459         C0007102                                       Colon cancer
# 325295      DOID:10657                               colonic lymphangioma
# 18998            94086                                              HSPB9
# 378484  UBERON:0004854                  gastrointestinal system mesentery
#
#                  Node_Type  irritable bowel syndrome  breast cancer  \
# 3846                  Gene                 -0.288685      -0.243891
# 326959             Disease                 -0.232002      -0.285991
# 18257                 Gene                 -0.274200      -0.251111
# 29084              Protein                 -0.274134      -0.251171
# 361133             Protein                 -0.352832      -0.195622
# 326958             Disease                 -0.140503      -0.352524
# 351164  PharmacologicClass                 -0.093946      -0.388816
# 11816                 Gene                 -0.323129      -0.214874
# 388239             Protein                 -0.186147      -0.312304
# 380037             Anatomy                 -0.073607      -0.331003
# 319107  PharmacologicClass                  0.189507      -0.486236
# 24153              Protein                 -0.195474      -0.306181
# 387260             Anatomy                 -0.107594      -0.320678
# 362162             Protein                 -0.241483      -0.243270
# 7223                  Gene                 -0.307271      -0.227303
# 5914                  Gene                 -0.038857      -0.381568
# 33647   PharmacologicClass                  0.186255      -0.500573
# 357701             Protein                 -0.284540      -0.241694
# 371810             Protein                 -0.511923      -0.085993
# 329510             Disease                 -0.306805      -0.247386
# 329683             Disease                 -0.270301      -0.263638
# 329425             Disease                 -0.289950      -0.249466
# 350552             Protein                 -0.487281      -0.126558
# 24151              Protein                 -0.241221      -0.277349
# 11675                 Gene                 -0.352888      -0.195558
# 351372  PharmacologicClass                 -0.248447      -0.242726
# 3065                  Gene                 -0.400270      -0.132419
# 30768           SideEffect                 -0.170584      -0.303604
# 3010                  Gene                 -0.428583      -0.105102
# 3861                  Gene                 -0.327846      -0.182712
# 16516                 Gene                 -0.397197      -0.119676
# 360819             Protein                 -0.285674      -0.259057
# 17096                 Gene                 -0.399615      -0.130953
# 363140             Protein                 -0.135783      -0.322487
# 5795                  Gene                 -0.228042      -0.268305
# 21803              Protein                 -0.283014      -0.253853
# 7426                  Gene                 -0.283152      -0.253734
# 370287             Protein                 -0.282076      -0.263468
# 929                   Gene                 -0.211733      -0.301310
# 22654              Protein                 -0.286066      -0.193970
# 329026             Disease                 -0.191705      -0.285508
# 4775                  Gene                 -0.497196      -0.053567
# 327058             Disease                 -0.270311      -0.263631
# 21719              Protein                 -0.195003      -0.223660
# 7504                  Gene                 -0.316081      -0.224858
# 327458             Disease                 -0.543779      -0.010160
# 29459           SideEffect                 -0.265862      -0.266114
# 325295             Disease                 -0.257639      -0.271405
# 18998                 Gene                 -0.162321      -0.283529
# 378484             Anatomy                 -0.103504      -0.297003
#
#         colon cancer  feature_importance
# 3846        1.793471            0.003483
# 326959      1.794596            0.002913
# 18257       1.785253            0.002819
# 29084       1.785324            0.002723
# 361133      1.757216            0.002700
# 326958      1.836302            0.002685
# 351164      1.869982            0.002609
# 11816       1.763237            0.002588
# 388239      1.789676            0.002502
# 380037      1.594569            0.002378
# 319107      1.545063            0.002375
# 24153       1.810138            0.002369
# 387260      1.638755            0.002307
# 362162      1.672579            0.002163
# 7223        1.773878            0.002101
# 5914        1.723454            0.002069
# 33647       1.604953            0.001938
# 357701      1.768887            0.001734
# 371810      1.701186            0.001636
# 329510      1.832016            0.001634
# 329683      1.822379            0.001475
# 329425      1.815193            0.001280
# 350552      1.795758            0.001078
# 24151       1.808667            0.000938
# 11675       1.757106            0.000715
# 351372      1.675311            0.000679
# 3065        1.624588            0.000678
# 30768       1.718516            0.000677
# 3010        1.583605            0.000661
# 3861        1.647607            0.000657
# 16516       1.565882            0.000648
# 360819      1.829194            0.000627
# 17096       1.616506            0.000602
# 363140      1.728725            0.000584
# 5795        1.743070            0.000561
# 21803       1.819630            0.000559
# 7426        1.819506            0.000545
# 370287      1.851454            0.000510
# 929         1.829942            0.000509
# 22654       1.570559            0.000463
# 329026      1.714579            0.000456
# 4775        1.544241            0.000451
# 327058      1.822379            0.000450
# 21719       1.476523            0.000448
# 7504        1.784168            0.000421
# 327458      1.475617            0.000404
# 29459       1.821012            0.000403
# 325295      1.821817            0.000393
# 18998       1.640050            0.000374
# 378484      1.526720            0.000368
